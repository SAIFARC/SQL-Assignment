# %% [markdown]
# #Theory

# %% [markdown]
# 1. Explain the fundamental differences between DDL, DML, and DQL commands in SQL. Provide one example for each type of command.
#
#
#  - DDL (Data Definition Language): Used to define or change the structure of the database.
#
# Example:
# CREATE TABLE Students (ID INT, Name VARCHAR(50));
#
# DML (Data Manipulation Language): Used to manage data inside tables.
#
# Example:
# INSERT INTO Students VALUES (1, 'Saif');
#
#
# DQL (Data Query Language): Used to retrieve data from tables.
#
# Example:
# SELECT * FROM Students;

# %% [markdown]
# 2. What is the purpose of SQL constraints? Name and describe three common types of constraints, providing a simple scenario where each would be useful.
#
#  - Constraints help maintain accuracy and reliability of data in a database.
#
# PRIMARY KEY: Ensures each record is unique.
# Example: StudentID in a Student table.
#
# FOREIGN KEY: Links one table to another.
# Example: CustomerID in Orders table refers to Customers table.
#
# NOT NULL: Ensures a column cannot have NULL values.
# Example: A field like Email should not be left empty.

# %% [markdown]
# 3. Explain the difference between LIMIT and OFFSET clauses in SQL. How would you use them together to retrieve the third page of results, assuming each page has 10 records?
#
#  - LIMIT sets how many records to display.
#
# OFFSET tells from which record to start displaying.
# To get the third page of results (page size = 10):
#
#   SELECT * FROM Products
# LIMIT 10 OFFSET 20;
#
# Here, OFFSET 20 skips the first 20 records and shows the next 10.

# %% [markdown]
# 4. What is a Common Table Expression (CTE) in SQL, and what are its main benefits? Provide a simple SQL example demonstrating its usage.
#
#  - A CTE is a temporary result set that can be used inside a SELECT, INSERT, UPDATE, or DELETE query.
# It makes queries easier to read and manage.
#
# Example:
# WITH HighSalary AS (
#   SELECT Name, Salary FROM Employees WHERE Salary > 50000
# )
# SELECT * FROM HighSalary;

# %% [markdown]
# 5. Describe the concept of SQL Normalization and its primary goals. Briefly explain the first three normal forms (1NF, 2NF, 3NF).
#
#  - Normalization organizes data to reduce redundancy and improve efficiency.
#
# 1NF: Each cell should hold only one value (no repeating groups).
#
# 2NF: Must be in 1NF, and all non-key columns depend on the entire primary key.
#
# 3NF: Must be in 2NF, and no non-key column should depend on another non-key column.
